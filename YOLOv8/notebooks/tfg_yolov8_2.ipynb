# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub
checks()  #reduce en tamaño la salida de la celda y resume la completitud de la instalación
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 29.9/201.2 GB disk)

# %% [markdown]
# Conexión con Google Drive para importar el dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Descomprimimos y guardamos el dataset en un directorio "/content/images"

# %%
# !mkdir /content/images
# !unzip -q '/content/gdrive/MyDrive/yolov8/dataset_grande.zip' -d /content/images

# %% [markdown]
# Ejecutamos entrenamiento con la arquitectura del modelo a entrenar y asociando en "data" el archivo yaml del dataset. También se establecen los parámetros necesarios para el entrenamiento.

# %%
# !yolo task=detect mode=train model=yolov8m data="/content/images/dataset_grande/data.yaml" epochs=50 imgsz=640
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# train: WARNING ⚠️ /content/images/dataset_grande/train/images/9999951_00000_d_0000144_jpg.rf.82ecd6144cc19d3fcafae6c5ce5ffd6e.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/images/dataset_grande/train/images/9999951_00000_d_0000145_jpg.rf.12167789b8cfd26834114e1f09b8cdf8.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/images/dataset_grande/train/images/9999951_00000_d_0000146_jpg.rf.512d6a6f80f2a4890592a99a93299192.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# ...

# %% [markdown]
# Finalmente en la carpeta runs/weights se pueden encontrar el modelo entrenado llamado best.pt. Además Ultralytics proporciona muchas gráficas y resultados que se pueden consultar en esta carpeta.
